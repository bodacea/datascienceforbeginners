# %% [markdown]
# # Text data representations

# %% [markdown]
# ## Example 'real' data: SIPA description, #migrantcrisis tweets
#
# SIPA text is taken from the Wikipedia entry about SIPA, https://en.wikipedia.org/wiki/School_of_International_and_Public_Affairs,_Columbia_University.
#
# Migrantcrisis tweets were read from the twitter search API (see notebook 3.2 Social Media Data), using hashtag #migrantcrisis, on 9th March 2016.

# %%
fsipa = open('example_data/sipatext.txt', 'r')
sipatext = fsipa.read()
fsipa.close()
print(sipatext)
# Out:
# The School of International and Public Affairs at Columbia University (also known at SIPA) is a public policy and international affairs school and one of Columbia's graduate and professional schools.
#
# Located on Columbia's Morningside Heights campus in the Borough ofManhattan, in New York City, the school has more than 19,000 alumni in more than 150 countries. SIPA's alumni include former heads of state, business leaders, journalists, diplomats, and elected representatives. Many graduates reach the upper echelons of central banks and treasuries, others go to energy companies, non-for-profits and social enterprises.[1] Half of SIPA’s nearly 1,400 students are international, coming from over 100 countries. SIPA has more than 70 full-time faculty and more than 200 adjunct professors, including the world's leading scholars on international relations.
#
# The school offers two traditional two-year master's degrees (Master of Public Administration or Master of International Affairs), an Executive MPA, an Environmental Science and Policy program, an Economic Policy Management program, a Development Practice degree, and a Ph.D. program in Sustainable Development. SIPA also offers a number of dual-degree programs with other Columbia University schools and, through the Global Public Policy Network (GPPN), offers international dual degree programs with the London School of Economics and Political Science, the Institut d'Études Politiques de Paris(Sciences Po), the Hertie School of Governance in Berlin, the University of Tokyo and the Lee Kuan Yew School of Public Policy at the National University of Singapore.[2]

# %%
import json
import pandas as pd

ftweets = open('example_data/migrantcrisis_tweets.json', 'r')
tweetdata = json.load(ftweets)
ftweets.close()
tweetframe = pd.DataFrame(tweetdata['statuses'])
tweetframe[['entities', 'text', 'user']]
# Out:
#                                              entities  \
# 0   {'urls': [{'indices': [26, 49], 'expanded_url'...
# 1   {'urls': [{'indices': [0, 23], 'expanded_url':...
# 2   {'urls': [{'indices': [53, 76], 'expanded_url'...
# 3   {'urls': [], 'symbols': [], 'user_mentions': [...
# 4   {'urls': [], 'symbols': [], 'user_mentions': [...
# 5   {'urls': [{'indices': [95, 118], 'expanded_url...
# 6   {'urls': [{'indices': [139, 140], 'expanded_ur...
# 7   {'urls': [], 'symbols': [], 'hashtags': [{'ind...
# 8   {'urls': [], 'symbols': [], 'user_mentions': [...
# 9   {'urls': [{'indices': [139, 140], 'expanded_ur...
# 10  {'urls': [{'indices': [33, 56], 'expanded_url'...
# 11  {'urls': [{'indices': [88, 111], 'expanded_url...
# 12  {'urls': [{'indices': [104, 127], 'expanded_ur...
# 13  {'urls': [], 'symbols': [], 'hashtags': [{'ind...
# 14  {'urls': [{'indices': [67, 90], 'expanded_url'...
#
#                                                  text  \
# 0   Stirile zilei - 9 martie: https://t.co/R3n6Vr8...
# 1   https://t.co/I09bHPUEyM via @youtube @guardian...
# 2   RT @ECentauri: GERMAN GOVT. PROMOTES INTERRACI...
# 3   RT @vladokrstevski: #NeoCommies\n#UDBA\n#Soros...
# 4   RT @ECentauri: 'I GOT A SOLUTION TO #migrantcr...
# 5   #Migrants - Feeling Unwanted In Germany, Some ...
# 6   RT @INTHENOWRT: This drone captures some 14,00...
# 7   People who moan about the migrant crisis.... 🖕...
# 8   RT @London_360: .@RitaOra delivers a personal ...
# 9   RT @INTHENOWRT: This drone captures some 14,00...
# 10  @lksriv but on the otherhand ...\nhttps://t.co...
# 11  @zoharfisher @TheEconomist wonder if she think...
# 12  RT @newint: #PhotoGallery | #MigrantCrisis: As...
# 13  Germany/Japan should both accept ALL of the wo...
# 14  RT @petersthoughts: The Death of the Most Gene...
#
#                                                  user
# 0   {'created_at': 'Thu Oct 13 17:44:25 +0000 2011...
# 1   {'created_at': 'Tue Feb 17 10:04:20 +0000 2009...
# 2   {'created_at': 'Tue Mar 19 16:54:09 +0000 2013...
# 3   {'created_at': 'Wed Jul 13 14:28:40 +0000 2011...
# 4   {'created_at': 'Sat Feb 05 05:43:38 +0000 2011...
# 5   {'created_at': 'Mon Sep 07 06:52:50 +0000 2015...
# 6   {'created_at': 'Tue Nov 20 10:18:29 +0000 2012...
# 7   {'created_at': 'Sun Jan 05 19:55:14 +0000 2014...
# 8   {'created_at': 'Tue Oct 28 17:24:30 +0000 2014...
# 9   {'created_at': 'Fri Jun 20 18:02:44 +0000 2014...
# 10  {'created_at': 'Sat Jan 01 18:02:27 +0000 2011...
# 11  {'created_at': 'Sat Jan 01 18:02:27 +0000 2011...
# 12  {'created_at': 'Wed Dec 11 12:35:02 +0000 2013...
# 13  {'created_at': 'Sun Nov 25 21:09:54 +0000 2012...
# 14  {'created_at': 'Sat Jan 01 18:02:27 +0000 2011...

# %% [markdown]
# ## Using the raw data
#
# Sometime you'll want to use the raw data itself as input to algorithms.  Examples of this include things like Twitter hashtags or user names, which are short and (hopefully) consistent.

# %% [markdown]
# ## Using Bags of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

count_vect = CountVectorizer()
word_counts = count_vect.fit_transform([sipatext])
print('{}'.format(word_counts))
print('{}'.format(count_vect.vocabulary_))
# Out:
#   (0, 120)	13
#   (0, 109)	7
#   (0, 83)	13
#   (0, 61)	6
#   (0, 13)	13
#   (0, 104)	5
#   (0, 9)	3
#   (0, 15)	3
#   (0, 23)	4
#   (0, 128)	4
#   (0, 10)	2
#   (0, 64)	1
#   (0, 114)	5
#   (0, 62)	1
#   (0, 95)	5
#   (0, 87)	1
#   (0, 50)	1
#   (0, 99)	1
#   (0, 110)	2
#   (0, 69)	1
#   (0, 86)	2
#   (0, 75)	1
#   (0, 55)	1
#   (0, 20)	1
#   (0, 57)	5
#   :	:
#   (0, 130)	2
#   (0, 89)	1
#   (0, 121)	1
#   (0, 46)	1
#   (0, 79)	1
#   (0, 49)	1
#   (0, 70)	1
#   (0, 35)	1
#   (0, 96)	1
#   (0, 60)	1
#   (0, 135)	1
#   (0, 97)	1
#   (0, 27)	1
#   (0, 92)	1
#   (0, 112)	1
#   (0, 94)	1
#   (0, 56)	1
#   (0, 48)	1
#   (0, 17)	1
#   (0, 124)	1
#   (0, 68)	1
#   (0, 65)	1
#   (0, 133)	1
#   (0, 77)	1
#   (0, 113)	1
# {'campus': 20, 'known': 64, 'reach': 105, 'two': 127, 'has': 53, 'an': 12, 'traditional': 125, 'program': 102, 'upper': 129, 'with': 130, 'companies': 25, 'degree': 28, 'faculty': 41, 'economic': 34, 'political': 96, 'mpa': 76, 'nearly': 78, 'professional': 99, 'policy': 95, 'offers': 84, 'and': 13, '150': 2, '200': 4, 'the': 120, '70': 6, '400': 5, 'include': 58, 'city': 22, 'including': 59, '100': 1, 'gppn': 49, 'programs': 103, 'over': 91, 'economics': 35, 'journalists': 63, 'sustainable': 118, 'half': 52, 'environmental': 39, 'banks': 16, 'professors': 100, 'than': 119, 'many': 72, 'number': 82, 'schools': 110, 'university': 128, 'administration': 8, 'yew': 133, 'affairs': 9, 'treasuries': 126, 'of': 83, 'elected': 36, 'adjunct': 7, 'sipa': 114, 'ph': 93, 'executive': 40, 'or': 88, 'lee': 68, 'for': 42, 'national': 77, 'enterprises': 38, 'students': 117, 'others': 90, 'state': 116, 'social': 115, 'hertie': 56, 'ofmanhattan': 85, 'other': 89, 'paris': 92, 'also': 10, 'london': 70, 'po': 94, 'kuan': 65, 'leaders': 66, 'coming': 24, 'management': 71, 'countries': 26, 'borough': 18, 'business': 19, 'from': 44, 'year': 132, 'berlin': 17, 'études': 135, 'more': 74, 'heights': 55, 'scholars': 108, 'practice': 98, 'global': 46, 'network': 79, 'morningside': 75, 'former': 43, 'in': 57, 'at': 15, 'de': 27, 'politiques': 97, 'sciences': 112, 'governance': 48, 'through': 121, 'is': 62, 'heads': 54, 'york': 134, 'science': 111, 'new': 80, 'tokyo': 124, 'graduate': 50, 'graduates': 51, 'time': 122, 'to': 123, 'public': 104, 'representatives': 107, 'international': 61, 'echelons': 33, 'institut': 60, 'master': 73, 'on': 86, 'world': 131, 'go': 47, '19': 3, 'one': 87, 'located': 69, 'diplomats': 31, 'non': 81, 'leading': 67, 'full': 45, 'singapore': 113, 'relations': 106, 'profits': 101, 'degrees': 29, 'development': 30, 'school': 109, 'energy': 37, '000': 0, 'columbia': 23, 'are': 14, 'central': 21, 'dual': 32, 'alumni': 11}

# %% [markdown]
# Let's have a more civilised look at that word count list, by turning it into a Pandas dataframe, sorted by count...

# %%
df = pd.DataFrame(word_counts.A, columns=count_vect.get_feature_names()).transpose()
df.columns = ['count']
df.sort_values(by='count', ascending=False)
# Out:
#                count
# and               13
# the               13
# of                13
# school             7
# international      6
# policy             5
# public             5
# in                 5
# sipa               5
# columbia           4
# than               4
# more               4
# university         4
# degree             3
# program            3
# at                 3
# master             3
# affairs            3
# offers             3
# an                 3
# alumni             2
# programs           2
# has                2
# schools            2
# science            2
# dual               2
# with               2
# development        2
# also               2
# two                2
# ...              ...
# faculty            1
# many               1
# include            1
# management         1
# london             1
# located            1
# 100                1
# leading            1
# leaders            1
# kuan               1
# known              1
# journalists        1
# is                 1
# institut           1
# including          1
# hertie             1
# for                1
# heights            1
# heads              1
# half               1
# graduates          1
# graduate           1
# gppn               1
# governance         1
# go                 1
# global             1
# full               1
# from               1
# former             1
# études             1
#
# [136 rows x 1 columns]

# %% [markdown]
# ## N-grams

# %%
count_vectn = CountVectorizer(ngram_range =(2, 2))
word_countsn = count_vectn.fit_transform([sipatext])

df_n = pd.DataFrame(word_countsn.A, columns=count_vectn.get_feature_names()).transpose()
df_n.columns = ['count']
df_n.sort_values(by='count', ascending=False)
# Out:
#                          count
# more than                    4
# school of                    4
# the school                   3
# public policy                3
# dual degree                  2
# of public                    2
# international affairs        2
# columbia university          2
# countries sipa               2
# of international             2
# degree programs              2
# programs with                2
# has more                     2
# master of                    2
# university of                2
# politiques de                1
# policy management            1
# policy at                    1
# policy network               1
# policy program               1
# political science            1
# program an                   1
# practice degree              1
# professional schools         1
# professors including         1
# profits and                  1
# po the                       1
# program development          1
# program in                   1
# public administration        1
# ...                        ...
# master degrees               1
# 100 countries                1
# morningside heights          1
# in sustainable               1
# in more                      1
# echelons of                  1
# from over                    1
# economic policy              1
# economics and                1
# elected representatives      1
# energy companies             1
# enterprises half             1
# environmental science        1
# executive mpa                1
# faculty and                  1
# for profits                  1
# former heads                 1
# full time                    1
# in berlin                    1
# global public                1
# go to                        1
# governance in                1
# gppn offers                  1
# graduate and                 1
# graduates reach              1
# half of                      1
# heads of                     1
# heights campus               1
# hertie school                1
# études politiques            1
#
# [215 rows x 1 columns]

# %% [markdown]
# ### Stopwords

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

count_vect2 = CountVectorizer(stop_words='english')
word_counts2 = count_vect2.fit_transform([sipatext])

df2 = pd.DataFrame(word_counts2.A, columns=count_vect2.get_feature_names()).transpose()
df2.columns = ['count']
df2.sort_values(by='count', ascending=False)
# Out:
#                count
# school             7
# international      6
# public             5
# policy             5
# sipa               5
# university         4
# columbia           4
# program            3
# degree             3
# affairs            3
# master             3
# offers             3
# programs           2
# schools            2
# dual               2
# science            2
# development        2
# countries          2
# alumni             2
# profits            1
# nearly             1
# mpa                1
# professors         1
# professional       1
# practice           1
# politiques         1
# number             1
# network            1
# ofmanhattan        1
# paris              1
# ...              ...
# 400                1
# 200                1
# 19                 1
# 150                1
# elected            1
# enterprises        1
# london             1
# environmental      1
# located            1
# lee                1
# 100                1
# leaders            1
# kuan               1
# known              1
# journalists        1
# institut           1
# including          1
# include            1
# hertie             1
# heights            1
# heads              1
# half               1
# graduates          1
# graduate           1
# gppn               1
# governance         1
# global             1
# faculty            1
# executive          1
# études             1
#
# [107 rows x 1 columns]

# %% [markdown]
# ## Using Term frequencies

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tf_transformer = TfidfTransformer(use_idf=False)
tf_features = tf_transformer.fit_transform(word_counts2)
print('{}'.format(tf_features))
# Out:
#   (0, 86)	0.372572406789
#   (0, 48)	0.319347777247
#   (0, 81)	0.266123147706
#   (0, 9)	0.159673888624
#   (0, 18)	0.212898518165
#   (0, 100)	0.212898518165
#   (0, 50)	0.0532246295412
#   (0, 91)	0.266123147706
#   (0, 72)	0.266123147706
#   (0, 39)	0.0532246295412
#   (0, 76)	0.0532246295412
#   (0, 87)	0.106449259082
#   (0, 55)	0.0532246295412
#   (0, 59)	0.0532246295412
#   (0, 43)	0.0532246295412
#   (0, 15)	0.0532246295412
#   (0, 13)	0.0532246295412
#   (0, 68)	0.0532246295412
#   (0, 64)	0.0532246295412
#   (0, 105)	0.0532246295412
#   (0, 17)	0.0532246295412
#   (0, 3)	0.0532246295412
#   (0, 0)	0.0532246295412
#   (0, 10)	0.106449259082
#   (0, 2)	0.0532246295412
#   :	:
#   (0, 95)	0.0532246295412
#   (0, 66)	0.0532246295412
#   (0, 26)	0.106449259082
#   (0, 80)	0.106449259082
#   (0, 36)	0.0532246295412
#   (0, 63)	0.0532246295412
#   (0, 38)	0.0532246295412
#   (0, 56)	0.0532246295412
#   (0, 29)	0.0532246295412
#   (0, 73)	0.0532246295412
#   (0, 47)	0.0532246295412
#   (0, 106)	0.0532246295412
#   (0, 74)	0.0532246295412
#   (0, 69)	0.0532246295412
#   (0, 89)	0.0532246295412
#   (0, 71)	0.0532246295412
#   (0, 44)	0.0532246295412
#   (0, 37)	0.0532246295412
#   (0, 12)	0.0532246295412
#   (0, 97)	0.0532246295412
#   (0, 54)	0.0532246295412
#   (0, 51)	0.0532246295412
#   (0, 104)	0.0532246295412
#   (0, 61)	0.0532246295412
#   (0, 90)	0.0532246295412

# %%
tfidf_transformer = TfidfTransformer(use_idf=True)
tfidf_features = tfidf_transformer.fit_transform(word_counts2)
print('{}'.format(tfidf_features))
# Out:
#   (0, 90)	0.0532246295412
#   (0, 61)	0.0532246295412
#   (0, 104)	0.0532246295412
#   (0, 51)	0.0532246295412
#   (0, 54)	0.0532246295412
#   (0, 97)	0.0532246295412
#   (0, 12)	0.0532246295412
#   (0, 37)	0.0532246295412
#   (0, 44)	0.0532246295412
#   (0, 71)	0.0532246295412
#   (0, 89)	0.0532246295412
#   (0, 69)	0.0532246295412
#   (0, 74)	0.0532246295412
#   (0, 106)	0.0532246295412
#   (0, 47)	0.0532246295412
#   (0, 73)	0.0532246295412
#   (0, 29)	0.0532246295412
#   (0, 56)	0.0532246295412
#   (0, 38)	0.0532246295412
#   (0, 63)	0.0532246295412
#   (0, 36)	0.0532246295412
#   (0, 80)	0.106449259082
#   (0, 26)	0.106449259082
#   (0, 66)	0.0532246295412
#   (0, 95)	0.0532246295412
#   :	:
#   (0, 2)	0.0532246295412
#   (0, 10)	0.106449259082
#   (0, 0)	0.0532246295412
#   (0, 3)	0.0532246295412
#   (0, 17)	0.0532246295412
#   (0, 105)	0.0532246295412
#   (0, 64)	0.0532246295412
#   (0, 68)	0.0532246295412
#   (0, 13)	0.0532246295412
#   (0, 15)	0.0532246295412
#   (0, 43)	0.0532246295412
#   (0, 59)	0.0532246295412
#   (0, 55)	0.0532246295412
#   (0, 87)	0.106449259082
#   (0, 76)	0.0532246295412
#   (0, 39)	0.0532246295412
#   (0, 72)	0.266123147706
#   (0, 91)	0.266123147706
#   (0, 50)	0.0532246295412
#   (0, 100)	0.212898518165
#   (0, 18)	0.212898518165
#   (0, 9)	0.159673888624
#   (0, 81)	0.266123147706
#   (0, 48)	0.319347777247
#   (0, 86)	0.372572406789

# %% [markdown]
# ## Using the NLTK library and corpora
#
# Corpora = lists of words, like stopwords, stemwords, grammar etc. for multiple languages.

# %% [markdown]
# ### Get NLTK resources
#
#
# WARNINGS:
#
# * You will have to conda install nltk before you can run this cell
# * And even when you ahve the NLTK library, you won't be able to run the cells below without the NLTK corpora.
#
# Run the cell below just once.
# * When you run nltk.download(), a popup window will appear.
# * Click on the "models" tab, then "punkt" then the "download" button
#
# If you want more, try clicking on "book" then "download".  If you ever wanted to have the whole of Basque grammar, then click around the tabs in this popup window: this is the place to get it!

# %%
import nltk
# nltk.download() #Uncomment this before running the cell
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# ## Word stemming
#
# Some of the words above are plurals, or heavily related to each other.  Word stemming removes all the word endings etc. to leave just the 'root' of each word.

# %%
from nltk import word_tokenize          
from nltk.stem.porter import PorterStemmer

#######
# based on http://www.cs.duke.edu/courses/spring14/compsci290/assignments/lab02.html
stemmer = PorterStemmer()
def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

def tokenize(text):
    tokens = word_tokenize(text)
    stems = stem_tokens(tokens, stemmer)
    return stems
######## 

count_vect3 = CountVectorizer(tokenizer=tokenize, stop_words='english') 
word_counts3 = count_vect3.fit_transform([sipatext])
#print('{}'.format(word_counts3))
#print('{}'.format(count_vect3.vocabulary_))

df3 = pd.DataFrame(word_counts3.A, columns=count_vect3.get_feature_names()).transpose()
df3.columns = ['count']
df3.sort_values(by='count', ascending=False)
# Out:
#              count
# ,               20
# school           9
# .                8
# intern           6
# 's               5
# polici           5
# public           5
# program          5
# columbia         4
# sipa             4
# univers          4
# (                4
# )                4
# scienc           3
# offer            3
# affair           3
# degre            3
# master           3
# ha               2
# includ           2
# econom           2
# countri          2
# graduat          2
# develop          2
# [                2
# alumni           2
# ]                2
# singapor         1
# two-year         1
# tradit           1
# ...            ...
# 2                1
# 19,000           1
# 150              1
# 100              1
# 1,400            1
# 1                1
# diplomat         1
# dual             1
# dual-degre       1
# echelon          1
# leader           1
# lead             1
# kuan             1
# known            1
# journalist       1
# herti            1
# height           1
# head             1
# half             1
# gppn             1
# govern           1
# global           1
# full-tim         1
# faculti          1
# execut           1
# environment      1
# enterpris        1
# energi           1
# elect            1
# york             1
#
# [111 rows x 1 columns]
