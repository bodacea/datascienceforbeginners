# %% [markdown]
# # Classifying text data

# %% [markdown]
# ## Get example dataset
#
# This is the 20 Newsgroups dataset

# %%
from sklearn.datasets import fetch_20newsgroups

fetch_20newsgroups

# Create some training and test data
categories = ['alt.atheism', 'soc.religion.christian',
              'comp.graphics', 'sci.med']

twenty_train = fetch_20newsgroups(subset='train', categories=categories)
twenty_test = fetch_20newsgroups(subset='test', categories=categories)

print('Keys: {}'.format(twenty_train.keys()))
print('Targets: {}'.format(twenty_train['target']))
print('First document: {}'.format(twenty_train['data'][0]))
# Out:
# Keys: dict_keys(['DESCR', 'target', 'target_names', 'description', 'data', 'filenames'])
# Targets: [1 1 3 ..., 2 2 2]
# First document: From: sd345@city.ac.uk (Michael Collier)
# Subject: Converting images to HP LaserJet III?
# Nntp-Posting-Host: hampton
# Organization: The City University
# Lines: 14
#
# Does anyone know of a good way (standard PC application/PD utility) to
# convert tif/img/tga files into LaserJet III format.  We would also like to
# do the same, converting to HPGL (HP plotter) files.
#
# Please email any response.
#
# Is this the correct group?
#
# Thanks in advance.  Michael.
# --
# Michael Collier (Programmer)                 The Computer Unit,
# Email: M.P.Collier@uk.ac.city                The City University,
# Tel: 071 477-8000 x3769                      London,
# Fax: 071 477-8565                            EC1V 0HB.

# %% [markdown]
# ## Count the words in each input document

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(twenty_train.data)

print("Number of documents and words: {}".format(X_train_counts.shape))
print("{}".format(X_train_counts))
print('{}'.format(count_vect.vocabulary_))
# Out:
# Number of documents and words: (2257, 35788)
#   (0, 14887)	1
#   (0, 29022)	1
#   (0, 8696)	4
#   (0, 4017)	2
#   (0, 33256)	2
#   (0, 21661)	3
#   (0, 9031)	3
#   (0, 31077)	1
#   (0, 9805)	2
#   (0, 17366)	1
#   (0, 32493)	4
#   (0, 16916)	2
#   (0, 19780)	2
#   (0, 17302)	2
#   (0, 23122)	1
#   (0, 25663)	1
#   (0, 16881)	1
#   (0, 16082)	1
#   (0, 23915)	1
#   (0, 32142)	5
#   (0, 33597)	2
#   (0, 20253)	1
#   (0, 587)	1
#   (0, 12051)	1
#   (0, 5201)	1
#   :	:
#   (2256, 13740)	1
#   (2256, 14662)	1
#   (2256, 20201)	1
#   (2256, 12443)	6
#   (2256, 30325)	3
#   (2256, 4610)	1
#   (2256, 33844)	1
#   (2256, 17354)	1
#   (2256, 26998)	1
#   (2256, 20277)	1
#   (2256, 20695)	1
#   (2256, 20702)	1
#   (2256, 9649)	1
#   (2256, 9086)	1
#   (2256, 26254)	1
#   (2256, 17133)	2
#   (2256, 4490)	1
#   (2256, 13720)	1
#   (2256, 5016)	1
#   (2256, 9632)	1
#   (2256, 11824)	1
#   (2256, 29993)	1
#   (2256, 1298)	1
#   (2256, 2375)	1
#   (2256, 3921)	1
# {'interdependence': 18160, 'sony': 30206, 'anullments': 5188, 'lithuanian': 20335, 'avhrr': 5923, 'pained': 24298, 'societies': 30089, 'turnip': 33084, 'ohsu': 23664, 'abscess': 3978, 'viruses': 34376, 'valinor': 34028, '804': 3082, '461': 2305, 'larynx': 19777, 'videocart': 34291, 'absorb': 3989, 'deliverer': 11059, 'mouth': 22316, 'despised': 11290, 'additive': 4268, 'drawn': 12227, 'ancients': 4990, 'cunningham': 10429, 'swivel': 31554, 'coli': 9003, 'joo': 18920, 'computerwetenschappen': 9345, 'williamt': 35070, 'forehead': 14623, 'hrvoje': 16951, 'final': 14302, 'maggia': 20799, 'punative': 26503, 'unverifiable': 33755, 'disparages': 11785, 'unlike': 33619, 'ummm': 33308, 'dean': 10805, 'postcard': 25650, 'pedestrians': 24717, 'leg': 19952, 'collaborations': 9010, 'dth': 12328, 'kemp_ja': 19235, 'arris': 5506, 'recipies': 27168, 'largo': 19770, 'svr4s': 31484, 'resized': 27796, 'u9126619': 33172, 'near': 22743, 'bcg': 6290, 'cypher': 10543, 'miles': 21760, 'undercooked': 33411, 'multiprocessor': 22445, 'mitre': 21982, 'thor': 32283, 'scary': 28808, 'addressed': 4274, 'ncifcrf': 22724, 'hio': 16631, '1993apr05': 1113, 'daycare': 10754, 'succumb': 31175, 'instituted': 18068, 'pricing': 26006, 'sauvie': 28733, 'uk': 33256, 'perverting': 24933, '1p8t1p': 1189, 'mathematicians': 21161, 'infections': 17796, 'law': 19841, 'schlegel': 28856, '381': 2108, 'unaware': 33340, 'relied': 27494, '2476v': 1614, '1993apr18': 1123, 'dundee': 12380, 'pals': 24341, 'dux': 12418, 'technik': 31873, 'freedom': 14822, 'sophistique': 30218, 'tiny': 32446, '7wx': 3055, 'fiery': 14257, 'dulcificum_': 12363, '13779': 570, 'crusade': 10298, 'penn': 24768, 'proprio': 26294, 'cfairman': 8217, 'executive': 13642, 'hassle': 16220, 'offertory': 23630, 'affirms': 4449, 'act': 4189, 'homelands': 16775, 'bombing': 6984, 'lepomis': 20029, '3dstusio': 2159, 'stretch': 30960, 'shore': 29558, 'timorese': 32434, 'unwillingness': 33762, 'texting': 32102, 'thanksgiving': 32136, 'heal': 16321, 'mont': 22170, 'scheming': 28845, 'sporanox': 30487, 'osteopporosis': 24006, 'coordinated': 9849, '1958': 1051, 'grasping': 15714, 'talks': 31726, 'thetech': 32231, 'gracious': 15640, 'latest': 19802, 'frontends': 14893, 'ride': 28072, 'inescapble': 17763, 'specially': 30344, 'margaret': 21008, 'rl': 28168, 'franciscan': 14783, 'falk': 13968, 'authoritarian': 5866, 'sacramento': 28532, 'modex': 22076, 'blockiness': 6855, 'sab': 28513, 'oblige': 23492, 'chb': 8370, 'hmmm': 16701, 'advocated': 4410, 'rewrite': 27991, 'distribute': 11900, 'direct': 11610, 'charlatans': 8339, 'polk': 25491, 'dictionnaire': 11491, 'intensive': 18132, 'mustrum': 22514, 'fishermen': 14365, '6435': 2682, 'knocking': 19453, '877261': 3201, '00index': 35, 'inflected': 17830, 'thighs': 32247, 'spider': 30422, 'unequivocally': 33491, '7000ft': 2818, 'tarr': 31787, 'electrolytes': 12749, 'wsu': 35374, 'emailed': 12835, 'regularly': 27396, 'commerical': 9139, 'embarks': 12853, 'gp120': 15624, '2396': 1584, 'derangement': 11199, 'additionally': 4266, 'rashly': 26932, 'micah': 21657, 'eph6': 13191, 'airborne': 4584, 'onto': 23768, 'ebs': 12535, 'agglutination': 4502, 'achses': 4142, 'martyrdom': 21083, 'header': 16309, 'kusumakar': 19609, 'philanthropic': 25022, '605': 2601, 'c5c7cn': 7565, '6812': 2765, 'illusion': 17340, 'tactical': 31691, 'tidbits': 32385, 'emergence': 12876, 'strikes': 30976, 'concentrates': 9367, 'acknowledge': 4153, 'trieste': 32900, 'crimson': 10198, '0094': 33, 'videoscan': 34293, 'prayerfully': 25764, 'tactic': 31690, '_this_': 3815, 'ic': 17185, 'supportable': 31365, 'opening': 23791, '11838': 418, 'okstate': 23680, 'fixing': 14389, 'tcsteven': 31839, 'france': 14779, 'kindly': 19375, '203': 1371, 'held': 16400, 'blackheads': 6774, 'transgress': 32759, 'lara': 19763, 'quiet': 26732, 'forgetfulness': 14652, 'credulously': 10170, 'kgn': 19303, 'incedently': 17585, 'klotman': 19425, 'kempja': 19236, 'uicsl': 33248, 'arun': 5546, 'xenoglossolalia': 35443, 'ladysmith': 19682, 'imposed':  ...

# %% [markdown]
# ## Convert the word counts into term frequencies

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer = TfidfTransformer(use_idf=True).fit(X_train_counts)
X_train_tfidf = tfidf_transformer.transform(X_train_counts)

print("Number of documents and words: {}".format(X_train_tfidf.shape))
print("{}".format(X_train_tfidf))
# Out:
# Number of documents and words: (2257, 35788)
#   (0, 230)	0.13487105543
#   (0, 12541)	0.13487105543
#   (0, 3166)	0.13487105543
#   (0, 14085)	0.0666645213786
#   (0, 20459)	0.109605855078
#   (0, 35416)	0.13487105543
#   (0, 3062)	0.107836029574
#   (0, 2326)	0.246455407094
#   (0, 177)	0.256120262391
#   (0, 31915)	0.0863191513116
#   (0, 33572)	0.093130075546
#   (0, 9338)	0.0496718454933
#   (0, 26175)	0.0849746094347
#   (0, 4378)	0.068661128808
#   (0, 17556)	0.0189454643496
#   (0, 32135)	0.0491023738045
#   (0, 15837)	0.0541740417987
#   (0, 9932)	0.063505656472
#   (0, 32270)	0.0238711427382
#   (0, 18474)	0.0199648817519
#   (0, 27836)	0.0689905081067
#   (0, 5195)	0.0310951485922
#   (0, 12833)	0.125601499991
#   (0, 25337)	0.0493588338398
#   (0, 25361)	0.119479381457
#   :	:
#   (2256, 6430)	0.0482527867471
#   (2256, 24052)	0.0381881683598
#   (2256, 22270)	0.0464220456686
#   (2256, 35638)	0.0532405739102
#   (2256, 32233)	0.0341379218213
#   (2256, 35157)	0.0281624509901
#   (2256, 4938)	0.0320317964628
#   (2256, 34923)	0.0315293006652
#   (2256, 5698)	0.0322617549522
#   (2256, 27031)	0.0462533505552
#   (2256, 14601)	0.023308516717
#   (2256, 21322)	0.0345381818062
#   (2256, 7766)	0.0301176820351
#   (2256, 12626)	0.0475318480817
#   (2256, 9338)	0.0524898258716
#   (2256, 17556)	0.0200202773803
#   (2256, 32270)	0.0252253990814
#   (2256, 18474)	0.0421950566279
#   (2256, 23610)	0.0385705908463
#   (2256, 587)	0.0630463398464
#   (2256, 20253)	0.0178216711483
#   (2256, 32142)	0.112420422672
#   (2256, 23915)	0.0187700094332
#   (2256, 31077)	0.0177507782189
#   (2256, 14887)	0.0177507782189

# %% [markdown]
# ## Train a classifier using these document term frequencies and the expected newsgroups

# %%
from sklearn.naive_bayes import MultinomialNB
nb_classifier = MultinomialNB().fit(X_train_tfidf, twenty_train.target)

print("Class counts: {}".format(nb_classifier.class_count_))
print("Priors: {}".format(nb_classifier.class_log_prior_))
# Out:
# Class counts: [ 480.  584.  594.  599.]
# Priors: [-1.54800567 -1.35189079 -1.33491246 -1.32653018]

# %% [markdown]
# ## Try your new classifier on some example data

# %%
# Create some test data, and process it to match the training data
docs_test = ['God is love', 'OpenGL on the GPU is fast']
X_new_counts = count_vect.transform(docs_test)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

# Run the classifier on the test data
predicted = nb_classifier.predict(X_new_tfidf)
for doc, category in zip(docs_test, predicted):
     print('{} => {}'.format(doc, twenty_train.target_names[category]))
# Out:
# God is love => soc.religion.christian
# OpenGL on the GPU is fast => comp.graphics
